# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/cars.csv")

# %%
df.sample(5)
# Out:
#            brand  km_driven    fuel         owner  selling_price
# 7750      Maruti      65204  Petrol   First Owner         325000
# 2087        Tata      30000  Diesel   First Owner        1200000
# 410        Lexus      20000  Petrol   First Owner        5150000
# 5537       Honda     178500  Petrol   Third Owner         200000
# 6549  Volkswagen      65000  Diesel  Second Owner         295000

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Land                6
# Force               6
# Isuzu               5
# Kia                 4
# Ambassador          4
# MG                  3
# Daewoo              3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %% [markdown]
# ### 1. OneHotEncoding using Pandas

# %%
pd.get_dummies(df, columns=['fuel', 'owner'], drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000         True     False        False
# 1       Skoda     120000         370000         True     False        False
# 2       Honda     140000         158000        False     False         True
# 3     Hyundai     127000         225000         True     False        False
# 4      Maruti     120000         130000        False     False         True
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000        False     False         True
# 8124  Hyundai     119000         135000         True     False        False
# 8125   Maruti     120000         382000         True     False        False
# 8126     Tata      25000         290000         True     False        False
# 8127     Tata      25000         290000         True     False        False
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                          False               False                 False
# 1                          False                True                 False
# 2                          False               False                 False
# 3                          False               False                 False
# 4                          False               False                 False
# ...                          ...                 ...                   ...
# 8123                       False               False                 False
# 8124                        True               False                 False
# 8125                       False               False                 False
# 8126                       False               False                 False
# 8127                       False               False                 False
#
#       owner_Third Owner
# 0                 False
# 1                 False
# 2                  True
# 3                 False
# 4                 False
# ...                 ...
# 8123              False
# 8124              False
# 8125              False
# 8126              False
# 8127              False
#
# [8128 rows x 10 columns]

# %% [markdown]
# ### 2. OneHotEncoding usnig Sklearn

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df.iloc[:, 0:4], df.iloc[:, -1], test_size=0.2, random_state=42
)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

# %%
X_train_new = ohe.fit_transform(X_train[['fuel','owner']])
X_test_new = ohe.transform(X_test[['fuel','owner']])
X_train_new.shape
# Out:
# (6502, 9)

# %% [markdown]
# ### 4. OneHotEncoding with Top Categories

# %%
counts = df['brand'].value_counts()
df['brand'].nunique()
threshold = 100
repl = counts[counts <= threshold].index
pd.get_dummies(df['brand'].replace(repl, 'uncommon')).sample(5)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 6185  False      False  False  False    False     False   False     True
# 1889  False      False  False  False    False     False    True    False
# 7586  False      False  False  False    False     False    True    False
# 684   False      False  False  False    False     False   False    False
# 4722  False      False  False  False     True     False   False    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 6185  False  False   False       False     False
# 1889  False  False   False       False     False
# 7586  False  False   False       False     False
# 684   False  False   False        True     False
# 4722  False  False   False       False     False
