# %% [markdown]
# ### **Performance Metrics On MultiClass Classification Problem**

# %%
from sklearn import metrics

# %%
C = 'Cat'
D = 'Dog'
F = 'Fox'

# %% [markdown]
# The precision for the Cat class is the number of correctly predicted Cat out of all predicted Cat
#
# The recall for Cat is the number of correctly predicted Cat phots out of the number of actual Cat
#
# ![image.png](attachment:image.png)

# %%
# True Values
y_true = [C,C,C,C,C,C, F,F,F,F,F,F,F,F,F,F, D,D,D,D,D,D,D,D,D]

# Predicted Values
y_pred = [C,C,C,C,D,F, C,C,C,C,C,C,D,D,F,F, C,C,C,D,D,D,D,D,D]

# Print the confusion matrix
print(metrics.confusion_matrix(y_true, y_pred))

# Print the precision and Recall, among other metrices
print(metrics.classification_report(y_true, y_pred, digits=3))
# Out:
# [[4 1 1]
#  [3 6 0]
#  [6 2 2]]
#               precision    recall  f1-score   support
#
#          Cat      0.308     0.667     0.421         6
#          Dog      0.667     0.667     0.667         9
#          Fox      0.667     0.200     0.308        10
#
#     accuracy                          0.480        25
#    macro avg      0.547     0.511     0.465        25
# weighted avg      0.581     0.480     0.464        25
